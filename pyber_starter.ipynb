# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# Combine the data into a single dataset
ride_data_complete_df = pd.merge(city_data_df, ride_data_df, how="left", on=["city", "city"])

# Display the data table for preview
ride_data_complete_df.head()


# Create a group based on the values in the 'type' column
city_name_group = ride_data_complete_df.groupby('type')

# Count how many times each maker appears in our group
count_city_type = city_name_group ['type' ].count()

#Print types
count_city_type
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: type, dtype: int64

# %%
# Create a group based on the values in the 'city' column
city_name_group = ride_data_complete_df.groupby('city')

# Count how many times each maker appears in our group
count_city = city_name_group ['city'].count()

city_name_group

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

# The max x value for chart is 100
x_limit = 100

# List of values 0-100, increasing by 1
x_axis = np.arange(0, x_limit, 1)

#Create array
xdata = ride_data_complete_df['city']
ydata = ride_data_complete_df['fare']

#plt.scatter(x=ride_data_complete_df ['city'], y=ride_data_complete_df ['fare'])
plt.scatter(xdata, ydata, marker="o", facecolors="yellow", edgecolors="black", s=x_axis, alpha=0.1)


# Incorporate the other graph properties
plt.title('Average Fare ($) Per City')
plt.xlabel('Total Number of Rides Per City')
plt.ylabel('Average Fare ($)')

# Show plot
plt.show()


# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
ride_data_complete_df
# Out:
#                  city  driver_count   type                 date   fare  \
# 0         Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1         Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2         Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3         Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# 4         Richardfort            38  Urban  2018-04-17 02:26:37  23.00
# 5         Richardfort            38  Urban  2018-04-21 03:44:04   9.54
# 6         Richardfort            38  Urban  2018-02-03 00:14:26  29.04
# 7         Richardfort            38  Urban  2018-02-08 15:50:12  16.55
# 8         Richardfort            38  Urban  2018-04-03 15:07:34  40.77
# 9         Richardfort            38  Urban  2018-02-19 14:09:20  27.11
# 10        Richardfort            38  Urban  2018-04-22 03:06:56  39.74
# 11        Richardfort            38  Urban  2018-01-31 14:51:01  43.92
# ...

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
#ride_data_complete_df.describe()

#Print types
count_city_type


plt.title("Total Fares by City Type")
plt.pie(city_name_group, labels=type, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)
plt.axis("equal")
plt.show()
# Save Figure
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-542be2fddc73> in <module>()
#      10
#      11 plt.title("Total Fares by City Type")
# ---> 12 plt.pie(city_name_group, labels=type, colors=colors,
#      13         autopct="%1.1f%%", shadow=True, startangle=90)
#      14 plt.axis("equal")
#
# NameError: name 'colors' is not defined

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
